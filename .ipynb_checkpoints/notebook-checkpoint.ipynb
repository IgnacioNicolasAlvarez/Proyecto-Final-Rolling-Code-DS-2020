# %% [markdown]
# # Librerias

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from IPython.display import display, HTML

from sklearn.model_selection import cross_val_score, train_test_split, GridSearchCV, KFold
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder, PowerTransformer

from plot_metric.functions import BinaryClassification
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score


from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import BernoulliNB, GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

# %% [markdown]
# # Configuracion General

# %%
# %matplotlib inline
plt.style.use('ggplot')

plt.rcParams["figure.figsize"] = (18,6)
sns.set_palette("husl")

ESTILO = "background-color:lightgrey; display:inline"
pd.options.mode.chained_assignment = None

TARGET = 'readmitted'
SEED = 42

# %%
def dropear_columnas(dataset, columnas):
    return dataset.drop(columnas, axis = 1)

# %%
df_raw = pd.read_csv("data\diabetic_data.csv")

# %% [markdown]
# # Vista del Dataset: Head/Tail

# %%
display(df_raw.head())
display(HTML('<br><hr><br>'))
display(df_raw.tail())
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# 0                 1  ...          No      No                   No
# 1                 3  ...          No      Up                   No
# 2                 2  ...          No      No                   No
# 3                 2  ...          No      Up                   No
# 4                 1  ...          No  Steady                   No
#
#    glipizide-metformin  glimepiride-pioglitazone  metformin-rosiglitazone  \
# 0                   No                        No                       No
# 1                   No                        No                       No
# 2                   No                        No                       No
# 3                   No                        No                       No
# 4                   No                        No                       No
#
#    metformin-pioglitazone  change diabetesMed readmitted
# 0                      No      No          No         NO
# 1                      No      Ch         Yes        >30
# 2                      No      No         Yes         NO
# 3                      No      Ch         Yes         NO
# 4                      No      Ch         Yes         NO
#
# [5 rows x 50 columns]
# <br><hr><br>
#         encounter_id  patient_nbr             race  gender      age weight  \
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)      ?
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)      ?
# 101763     443854148     41088789        Caucasian    Male  [70-80)      ?
# 101764     443857166     31693671        Caucasian  Female  [80-90)      ?
# 101765     443867222    175429310        Caucasian    Male  [70-80)      ?
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
# 101761                  1                         3                    7
# 101762                  1                         4                    5
# 101763                  1                         1                    7
# 101764                  2                         3                    7
# 101765                  1                         1                    7
#
#         time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# 101761                 3  ...          No    Down                   No
# 101762                 5  ...          No  Steady                   No
# 101763                 1  ...          No    Down                   No
# 101764                10  ...          No      Up                   No
# 101765                 6  ...          No      No                   No
#
#         glipizide-metformin  glimepiride-pioglitazone  \
# 101761                   No                        No
# 101762                   No                        No
# 101763                   No                        No
# 101764                   No                        No
# 101765                   No                        No
#
#         metformin-rosiglitazone  metformin-pioglitazone  change diabetesMed  \
# 101761                       No                      No      Ch         Yes
# 101762                       No                      No      No         Yes
# 101763                       No                      No      Ch         Yes
# 101764                       No                      No      Ch         Yes
# 101765                       No                      No      No          No
#
#        readmitted
# 101761        >30
# 101762         NO
# 101763         NO
# 101764         NO
# 101765         NO
#
# [5 rows x 50 columns]

# %%
df_raw = dropear_columnas(df_raw, ['encounter_id', 'patient_nbr'])

# %% [markdown]
# # Información sobre el Dataset

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101766 entries, 0 to 101765
# Data columns (total 48 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   race                      101766 non-null  object
#  1   gender                    101766 non-null  object
#  2   age                       101766 non-null  object
#  3   weight                    101766 non-null  object
#  4   admission_type_id         101766 non-null  int64
#  5   discharge_disposition_id  101766 non-null  int64
#  6   admission_source_id       101766 non-null  int64
#  7   time_in_hospital          101766 non-null  int64
#  8   payer_code                101766 non-null  object
#  9   medical_specialty         101766 non-null  object
#  10  num_lab_procedures        101766 non-null  int64
#  11  num_procedures            101766 non-null  int64
#  12  num_medications           101766 non-null  int64
#  13  number_outpatient         101766 non-null  int64
#  14  number_emergency          101766 non-null  int64
#  15  number_inpatient          101766 non-null  int64
#  16  diag_1                    101766 non-null  object
#  17  diag_2                    101766 non-null  object
#  18  diag_3                    101766 non-null  object
#  19  number_diagnoses          101766 non-null  int64
#  20  max_glu_serum             101766 non-null  object
#  21  A1Cresult                 101766 non-null  object
#  22  metformin                 101766 non-null  object
#  23  repaglinide               101766 non-null  object
#  24  nateglinide               101766 non-null  object
#  25  chlorpropamide            101766 non-null  object
#  26  glimepiride               101766 non-null  object
#  27  acetohexamide             101766 non-null  object
#  28  glipizide                 101766 non-null  object
#  29  glyburide                 101766 non-null  object
#  30  tolbutamide               101766 non-null  object
#  31  pioglitazone              101766 non-null  object
#  32  rosiglitazone             101766 non-null  object
#  33  acarbose                  101766 non-null  object
#  34  miglitol                  101766 non-null  object
#  35  troglitazone              101766 non-null  object
#  36  tolazamide                101766 non-null  object
#  37  examide                   101766 non-null  object
#  38  citoglipton               101766 non-null  object
#  39  insulin                   101766 non-null  object
#  40  glyburide-metformin       101766 non-null  object
#  41  glipizide-metformin       101766 non-null  object
#  42  glimepiride-pioglitazone  101766 non-null  object
#  43  metformin-rosiglitazone   101766 non-null  object
#  44  metformin-pioglitazone    101766 non-null  object
#  45  change                    101766 non-null  object
#  46  diabetesMed               101766 non-null  object
#  47  readmitted                101766 non-null  object
# dtypes: int64(11), object(37)
# memory usage: 37.3+ MB

# %%
df_raw.drop_duplicates(inplace=True)

# %% [markdown]
# # Descripción del Dataset

# %%
display(df_raw.describe().T)
display(df_raw.describe(include=[object]))
# Out:
#                              count       mean        std  min   25%   50%  \
# admission_type_id         101766.0   2.024006   1.445403  1.0   1.0   1.0
# discharge_disposition_id  101766.0   3.715642   5.280166  1.0   1.0   1.0
# admission_source_id       101766.0   5.754437   4.064081  1.0   1.0   7.0
# time_in_hospital          101766.0   4.395987   2.985108  1.0   2.0   4.0
# num_lab_procedures        101766.0  43.095641  19.674362  1.0  31.0  44.0
# num_procedures            101766.0   1.339730   1.705807  0.0   0.0   1.0
# num_medications           101766.0  16.021844   8.127566  1.0  10.0  15.0
# number_outpatient         101766.0   0.369357   1.267265  0.0   0.0   0.0
# number_emergency          101766.0   0.197836   0.930472  0.0   0.0   0.0
# number_inpatient          101766.0   0.635566   1.262863  0.0   0.0   0.0
# number_diagnoses          101766.0   7.422607   1.933600  1.0   6.0   8.0
#
#                            75%    max
# admission_type_id          3.0    8.0
# discharge_disposition_id   4.0   28.0
# admission_source_id        7.0   25.0
# time_in_hospital           6.0   14.0
# num_lab_procedures        57.0  132.0
# num_procedures             2.0    6.0
# num_medications           20.0   81.0
# number_outpatient          0.0   42.0
# number_emergency           0.0   76.0
# number_inpatient           1.0   21.0
# number_diagnoses           9.0   16.0
#              race  gender      age  weight payer_code medical_specialty  \
# count      101766  101766   101766  101766     101766            101766
# unique          6       3       10      10         18                73
# top     Caucasian  Female  [70-80)       ?          ?                 ?
# freq        76099   54708    26068   98569      40256             49949
#
#         diag_1  diag_2  diag_3 max_glu_serum  ... citoglipton insulin  \
# count   101766  101766  101766        101766  ...      101766  101766
# unique     717     749     790             4  ...           1       4
# top        428     276     250          None  ...          No      No
# freq      6862    6752   11555         96420  ...      101766   47383
#
#        glyburide-metformin glipizide-metformin glimepiride-pioglitazone  \
# count               101766              101766                   101766
# unique                   4                   2                        2
# top                     No                  No                       No
# freq                101060              101753                   101765
#
#        metformin-rosiglitazone metformin-pioglitazone  change diabetesMed  \
# count                   101766                 101766  101766      101766
# unique                       2                      2       2           2
# top                         No                     No      No         Yes
# freq                    101764                 101765   54755       78363
#
#        readmitted
# count      101766
# unique          3
# top            NO
# freq        54864
#
# [4 rows x 37 columns]

# %% [markdown]
# # Comprobación de Nulos

# %%
df_raw.isnull().sum()
# Out:
# race                        0
# gender                      0
# age                         0
# weight                      0
# admission_type_id           0
# discharge_disposition_id    0
# admission_source_id         0
# time_in_hospital            0
# payer_code                  0
# medical_specialty           0
# num_lab_procedures          0
# num_procedures              0
# num_medications             0
# number_outpatient           0
# number_emergency            0
# number_inpatient            0
# diag_1                      0
# diag_2                      0
# diag_3                      0
# number_diagnoses            0
# max_glu_serum               0
# A1Cresult                   0
# metformin                   0
# repaglinide                 0
# nateglinide                 0
# chlorpropamide              0
# glimepiride                 0
# acetohexamide               0
# glipizide                   0
# glyburide                   0
# tolbutamide                 0
# pioglitazone                0
# rosiglitazone               0
# acarbose                    0
# miglitol                    0
# troglitazone                0
# tolazamide                  0
# examide                     0
# citoglipton                 0
# insulin                     0
# glyburide-metformin         0
# glipizide-metformin         0
# glimepiride-pioglitazone    0
# metformin-rosiglitazone     0
# metformin-pioglitazone      0
# change                      0
# diabetesMed                 0
# readmitted                  0
# dtype: int64

# %% [markdown]
# # EDA Univariable

# %%
columnas_cat      = []
columnas_box_cox  = []
columnas_dropear  = []
columnas_num      = []

# %% [markdown]
# ## Race

# %%
display(df_raw['race'].value_counts(normalize=True))
# Out:
# Caucasian          0.747784
# AfricanAmerican    0.188766
# ?                  0.022336
# Hispanic           0.020017
# Other              0.014799
# Asian              0.006299
# Name: race, dtype: float64

# %%
sns.countplot(x=df_raw['race'], 
              order = df_raw['race'].value_counts().index,
              hue=df_raw['readmitted']);

# %%
columnas_cat.append('race')
df_raw['race']=df_raw['race'].fillna('UNK')

# %% [markdown]
# ## Gender

# %%
display(df_raw['gender'].value_counts())
# Out:
# Female             54708
# Male               47055
# Unknown/Invalid        3
# Name: gender, dtype: int64

# %%
columnas_cat.append('gender')

# %% [markdown]
# ## Age

# %%
display(df_raw['age'].value_counts(normalize=True))
# Out:
# [70-80)     0.256156
# [60-70)     0.220928
# [50-60)     0.169565
# [80-90)     0.168986
# [40-50)     0.095169
# [30-40)     0.037095
# [90-100)    0.027445
# [20-30)     0.016282
# [10-20)     0.006790
# [0-10)      0.001582
# Name: age, dtype: float64

# %%
sns.countplot(x=df_raw['age'], 
              order = df_raw['age'].value_counts().index,
              hue=df_raw['readmitted']);

# %%
columnas_cat.append('age')

# %% [markdown]
# ## Weight

# %%
display(df_raw['weight'].value_counts(normalize=True))
# Out:
# ?            0.968585
# [75-100)     0.013128
# [50-75)      0.008814
# [100-125)    0.006142
# [125-150)    0.001425
# [25-50)      0.000953
# [0-25)       0.000472
# [150-175)    0.000344
# [175-200)    0.000108
# >200         0.000029
# Name: weight, dtype: float64

# %%
columnas_dropear.append('weight')

# %%
df_raw['tiene_weight'] = df_raw['weight'].notnull().astype('int')
columnas_cat.append('tiene_weight')

# %% [markdown]
# ## Admission type id

# %%
display(df_raw['admission_type_id'].value_counts(normalize=True))
# Out:
# 1    0.530531
# 3    0.185416
# 2    0.181593
# 6    0.051992
# 5    0.047020
# 8    0.003144
# 7    0.000206
# 4    0.000098
# Name: admission_type_id, dtype: float64

# %%
sns.countplot(x=df_raw['admission_type_id'], 
              order = df_raw['admission_type_id'].value_counts().index,
              hue=df_raw['readmitted']);

# %%
columnas_cat.append('admission_type_id')

# %% [markdown]
# ## Discharge disposition id

# %%
display(df_raw['discharge_disposition_id'].value_counts())
# Out:
# 1     60234
# 3     13954
# 6     12902
# 18     3691
# 2      2128
# 22     1993
# 11     1642
# 5      1184
# 25      989
# 4       815
# 7       623
# 23      412
# 13      399
# 14      372
# 28      139
# 8       108
# 15       63
# 24       48
# 9        21
# 17       14
# 16       11
# 19        8
# 10        6
# 27        5
# 12        3
# 20        2
# Name: discharge_disposition_id, dtype: int64

# %%
sns.countplot(x=df_raw['discharge_disposition_id'], 
              order = df_raw['discharge_disposition_id'].value_counts().index,
              hue=df_raw['readmitted']);

# %%
columnas_cat.append('discharge_disposition_id')

# %% [markdown]
# ## Admission source id

# %%
display(df_raw['admission_source_id'].value_counts(normalize=True))
# Out:
# 7     0.564963
# 1     0.290519
# 17    0.066633
# 4     0.031317
# 6     0.022247
# 2     0.010848
# 5     0.008402
# 3     0.001838
# 20    0.001582
# 9     0.001228
# 8     0.000157
# 22    0.000118
# 10    0.000079
# 11    0.000020
# 14    0.000020
# 25    0.000020
# 13    0.000010
# Name: admission_source_id, dtype: float64

# %%
sns.countplot(x=df_raw['admission_source_id'], 
              order = df_raw['admission_source_id'].value_counts().index,
              hue=df_raw['readmitted']);

# %%
columnas_cat.append('admission_source_id')

# %% [markdown]
# ## Time in Hospital

# %%
display(df_raw['time_in_hospital'].value_counts(normalize=True))
# Out:
# 3     0.174479
# 2     0.169251
# 1     0.139614
# 4     0.136824
# 5     0.097931
# 6     0.074082
# 7     0.057573
# 8     0.043148
# 9     0.029499
# 10    0.023014
# 11    0.018228
# 12    0.014229
# 13    0.011890
# 14    0.010239
# Name: time_in_hospital, dtype: float64

# %%
sns.countplot(x=df_raw['time_in_hospital'], 
              order = df_raw['time_in_hospital'].value_counts().index,
              hue=df_raw['readmitted']);

# %%
columnas_num.append('time_in_hospital')

# %% [markdown]
# ## Payer code

# %%
display(df_raw['payer_code'].value_counts(normalize=True))
# Out:
# ?     0.395574
# MC    0.318761
# HM    0.061651
# SP    0.049201
# BC    0.045742
# MD    0.034707
# CP    0.024890
# UN    0.024055
# CM    0.019034
# OG    0.010151
# PO    0.005817
# DM    0.005395
# CH    0.001435
# WC    0.001327
# OT    0.000934
# MP    0.000776
# SI    0.000540
# FR    0.000010
# Name: payer_code, dtype: float64

# %%
sns.countplot(x=df_raw['payer_code'], 
              order = df_raw['payer_code'].value_counts().index,
              hue=df_raw['readmitted']);

# %%
columnas_cat.append('payer_code')

# %%
df_raw['payer_code'] = df_raw['payer_code'].fillna('UNK')

# %% [markdown]
# ## Medical Specialty

# %%
display(df_raw['medical_specialty'].value_counts(normalize=True))
# Out:
# ?                         0.490822
# InternalMedicine          0.143810
# Emergency/Trauma          0.074337
# Family/GeneralPractice    0.073109
# Cardiology                0.052591
#                             ...
# Perinatology              0.000010
# Proctology                0.000010
# Neurophysiology           0.000010
# Dermatology               0.000010
# SportsMedicine            0.000010
# Name: medical_specialty, Length: 73, dtype: float64

# %%
sns.countplot(x=df_raw['medical_specialty'], 
              order = df_raw['medical_specialty'].value_counts().index);
plt.xticks(rotation = 90);

# %%
columnas_cat.append('medical_specialty')

# %%
df_raw['medical_specialty']=df_raw['medical_specialty'].fillna('UNK')

# %%
top_10=['UNK','InternalMedicine',
        'Emergency/Trauma','Family/GeneralPractice','Cardiology','Surgery-General',
        'Nephrology','Orthopedics','Orthopedics-Reconstructive','Radiologist']

df_raw.loc[~df_raw['medical_specialty'].isin(top_10), 'medical_specialty'] = 'Other'

# %% [markdown]
# ## N° Lab Procedures

# %%
fig, axs = plt.subplots(2, figsize = (14,6), sharex = True)

sns.boxplot(x=df_raw['num_lab_procedures'], ax=axs[0]);
sns.histplot(
    df_raw,
    x="num_lab_procedures",
    multiple="stack",
    edgecolor=".3",
    linewidth=.5,
    ax=axs[1]
);

# %% [markdown]
# ## N° Procedures

# %%
display(df_raw['num_procedures'].value_counts(normalize=True))
# Out:
# 0    0.458424
# 1    0.203821
# 2    0.124963
# 3    0.092791
# 6    0.048680
# 4    0.041075
# 5    0.030246
# Name: num_procedures, dtype: float64

# %%
sns.countplot(x=df_raw['num_procedures'], 
              order = df_raw['num_procedures'].value_counts().index,
              hue=df_raw['readmitted']);

# %%
columnas_cat.append('num_procedures')

# %% [markdown]
# ## N° Medications

# %%
fig, axs = plt.subplots(2, figsize = (14,6), sharex = True)

sns.boxplot(x=df_raw['num_medications'], ax=axs[0]);
sns.histplot(
    df_raw,
    x="num_medications",
    multiple="stack",
    edgecolor=".3",
    linewidth=.5,
    ax=axs[1]
);

# %%
columnas_num.append("num_medications")

# %% [markdown]
# ## N° Outpatient

# %%
fig, axs = plt.subplots(2, figsize = (14,6), sharex = True)

sns.boxplot(x=df_raw['number_outpatient'], ax=axs[0]);
sns.histplot(
    df_raw,
    x="number_outpatient",
    multiple="stack",
    edgecolor=".3",
    linewidth=.5,
    ax=axs[1]
);

# %%
columnas_num.append("number_outpatient")
columnas_box_cox.append("number_outpatient")

# %% [markdown]
# ## N° emergency

# %%
fig, axs = plt.subplots(2, figsize = (14,6), sharex = True)

sns.boxplot(x=df_raw['number_emergency'], ax=axs[0]);
sns.histplot(
    df_raw,
    x="number_emergency",
    multiple="stack",
    edgecolor=".3",
    linewidth=.5,
    ax=axs[1]
);

# %%
columnas_num.append("number_emergency")
columnas_box_cox.append("number_emergency")

# %% [markdown]
# ## N° inpatient

# %%
fig, axs = plt.subplots(2, figsize = (14,6), sharex = True)

sns.boxplot(x=df_raw['number_inpatient'], ax=axs[0]);
sns.histplot(
    df_raw,
    x="number_inpatient",
    multiple="stack",
    edgecolor=".3",
    linewidth=.5,
    ax=axs[1]
);

# %%
columnas_num.append('number_inpatient')

# %% [markdown]
# ## Diagnostic 1

# %%
display(df_raw['diag_1'].value_counts(normalize=True))
# Out:
# 428    0.067429
# 414    0.064668
# 786    0.039463
# 410    0.035513
# 486    0.034471
#          ...
# V25    0.000010
# 842    0.000010
# 837    0.000010
# 827    0.000010
# 833    0.000010
# Name: diag_1, Length: 717, dtype: float64

# %%
sns.countplot(x=df_raw['diag_1'], 
              order = df_raw['diag_1'].value_counts().index);
plt.xticks(rotation = 90);

# %%
columnas_dropear.append('diag_1')

# %% [markdown]
# ## Diagnostic 2

# %%
display(df_raw['diag_2'].value_counts(normalize=True))
# Out:
# 276     0.066348
# 428     0.065464
# 250     0.059656
# 427     0.049486
# 401     0.036712
#           ...
# 975     0.000010
# 52      0.000010
# 364     0.000010
# E915    0.000010
# V25     0.000010
# Name: diag_2, Length: 749, dtype: float64

# %%
sns.countplot(x=df_raw['diag_2'], 
              order = df_raw['diag_2'].value_counts().index);
plt.xticks(rotation = 90);

# %%
columnas_dropear.append('diag_2')

# %% [markdown]
# ## Diagnostic 3

# %%
display(df_raw['diag_3'].value_counts(normalize=True))
# Out:
# 250     0.113545
# 401     0.081452
# 276     0.050852
# 428     0.044976
# 427     0.038864
#           ...
# 671     0.000010
# 732     0.000010
# E966    0.000010
# 841     0.000010
# V01     0.000010
# Name: diag_3, Length: 790, dtype: float64

# %%
sns.countplot(x=df_raw['diag_3'], 
              order = df_raw['diag_3'].value_counts().index);
plt.xticks(rotation = 90);

# %%
columnas_dropear.append('diag_3')

# %% [markdown]
# ## N° diagnoses

# %%
fig, axs = plt.subplots(2, figsize = (14,6), sharex = True)

sns.boxplot(x=df_raw['number_diagnoses'], ax=axs[0]);
sns.histplot(
    df_raw,
    x="number_diagnoses",
    multiple="stack",
    edgecolor=".3",
    linewidth=.5,
    ax=axs[1],
);

# %%
columnas_num.append('number_diagnoses')

# %% [markdown]
# ## max glu serum

# %%
display(df_raw['max_glu_serum'].value_counts(normalize=True))
# Out:
# None    0.947468
# Norm    0.025519
# >200    0.014592
# >300    0.012421
# Name: max_glu_serum, dtype: float64

# %%
sns.countplot(x = 'max_glu_serum', 
              order = df_raw['max_glu_serum'].value_counts().index,
              data = df_raw,
              hue='readmitted')

plt.xticks(rotation = 90);

# %%
columnas_dropear.append('max_glu_serum')

# %% [markdown]
# ## A1 Cresult

# %%
display(df_raw['A1Cresult'].value_counts(normalize=True))
# Out:
# None    0.832773
# >8      0.080734
# Norm    0.049034
# >7      0.037458
# Name: A1Cresult, dtype: float64

# %%
sns.countplot(x = 'A1Cresult', 
              order = df_raw['A1Cresult'].value_counts().index,
              data = df_raw,
              hue='readmitted')
plt.xticks(rotation = 90);

# %%
columnas_dropear.append('A1Cresult')

# %% [markdown]
# ## Metformin

# %%
display(df_raw['metformin'].value_counts(normalize=True))
# Out:
# No        0.803589
# Steady    0.180276
# Up        0.010485
# Down      0.005650
# Name: metformin, dtype: float64

# %%
sns.countplot(x = 'metformin', 
              order = df_raw['metformin'].value_counts().index,
              data = df_raw,
              hue='readmitted')
plt.xticks(rotation = 90);

# %%
columnas_dropear.append('metformin')

# %% [markdown]
# ## Repaglinide

# %%
display(df_raw['repaglinide'].value_counts(normalize=True))
# Out:
# No        0.984877
# Steady    0.013600
# Up        0.001081
# Down      0.000442
# Name: repaglinide, dtype: float64

# %%
sns.countplot(x = 'repaglinide', 
              order = df_raw['repaglinide'].value_counts().index,
              data = df_raw,
              hue='readmitted')
plt.xticks(rotation = 90);

# %%
columnas_dropear.append('repaglinide')

# %% [markdown]
# ## Nateglinide

# %%
display(df_raw['nateglinide'].value_counts(normalize=True))
# Out:
# No        0.993092
# Steady    0.006564
# Up        0.000236
# Down      0.000108
# Name: nateglinide, dtype: float64

# %%
sns.countplot(x = 'nateglinide', 
              order = df_raw['nateglinide'].value_counts().index,
              data = df_raw,
              hue='readmitted')
plt.xticks(rotation = 90);

# %%
columnas_dropear.append('nateglinide')

# %% [markdown]
# ## Chlorpropamide

# %%
display(df_raw['chlorpropamide'].value_counts(normalize=True))
# Out:
# No        0.999155
# Steady    0.000776
# Up        0.000059
# Down      0.000010
# Name: chlorpropamide, dtype: float64

# %%
sns.countplot(x = 'chlorpropamide', 
              order = df_raw['chlorpropamide'].value_counts().index,
              data = df_raw,
              hue='readmitted')
plt.xticks(rotation = 90);

# %%
columnas_dropear.append('chlorpropamide')

# %% [markdown]
# ## Glimepiride

# %%
display(df_raw['glimepiride'].value_counts(normalize=True))
# Out:
# No        0.948991
# Steady    0.045890
# Up        0.003213
# Down      0.001906
# Name: glimepiride, dtype: float64

# %%
sns.countplot(x = 'glimepiride', 
              order = df_raw['glimepiride'].value_counts().index,
              data = df_raw,
              hue='readmitted')
plt.xticks(rotation = 90);

# %%
columnas_dropear.append('glimepiride')

# %% [markdown]
# ## Acetohexamide

# %%
display(df_raw['acetohexamide'].value_counts(normalize=True))
# Out:
# No        0.99999
# Steady    0.00001
# Name: acetohexamide, dtype: float64

# %%
sns.countplot(x = 'acetohexamide', 
              order = df_raw['acetohexamide'].value_counts().index,
              data = df_raw,
              hue='readmitted')
plt.xticks(rotation = 90);

# %%
columnas_dropear.append('acetohexamide')

# %% [markdown]
# ## Glyburide

# %%
display(df_raw['glyburide'].value_counts(normalize=True))
# Out:
# No        0.895348
# Steady    0.091131
# Up        0.007979
# Down      0.005542
# Name: glyburide, dtype: float64

# %%
sns.countplot(x = 'glyburide', 
              order = df_raw['glyburide'].value_counts().index,
              data = df_raw,
              hue='readmitted')
plt.xticks(rotation = 90);

# %%
columnas_dropear.append('glyburide')

# %% [markdown]
# ## Tolbutamide

# %%
display(df_raw['tolbutamide'].value_counts(normalize=True))
# Out:
# No        0.999774
# Steady    0.000226
# Name: tolbutamide, dtype: float64

# %%
sns.countplot(x = 'tolbutamide', 
              order = df_raw['tolbutamide'].value_counts().index,
              data = df_raw,
              hue='readmitted')
plt.xticks(rotation = 90);

# %%
columnas_dropear.append('tolbutamide')

# %% [markdown]
# ## Pioglitazone

# %%
display(df_raw['pioglitazone'].value_counts(normalize=True))
# Out:
# No        0.927992
# Steady    0.068549
# Up        0.002299
# Down      0.001160
# Name: pioglitazone, dtype: float64

# %%
sns.countplot(x = 'pioglitazone', 
              order = df_raw['pioglitazone'].value_counts().index,
              data = df_raw,
              hue='readmitted')
plt.xticks(rotation = 90);

# %%
columnas_dropear.append('pioglitazone')

# %% [markdown]
# ## Rosiglitazone

# %%
display(df_raw['rosiglitazone'].value_counts(normalize=True))
# Out:
# No        0.937455
# Steady    0.059941
# Up        0.001749
# Down      0.000855
# Name: rosiglitazone, dtype: float64

# %%
sns.countplot(x = 'rosiglitazone', 
              order = df_raw['rosiglitazone'].value_counts().index,
              data = df_raw,
              hue='readmitted')
plt.xticks(rotation = 90);

# %%
columnas_dropear.append('rosiglitazone')

# %% [markdown]
# ## Acarbose

# %%
display(df_raw['acarbose'].value_counts(normalize=True))
# Out:
# No        0.996973
# Steady    0.002899
# Up        0.000098
# Down      0.000029
# Name: acarbose, dtype: float64

# %%
sns.countplot(x = 'acarbose', 
              order = df_raw['acarbose'].value_counts().index,
              data = df_raw,
              hue='readmitted')
plt.xticks(rotation = 90);

# %%
columnas_dropear.append('acarbose')

# %% [markdown]
# ## Miglitol

# %%
display(df_raw['miglitol'].value_counts(normalize=True))
# Out:
# No        0.999627
# Steady    0.000305
# Down      0.000049
# Up        0.000020
# Name: miglitol, dtype: float64

# %%
sns.countplot(x = 'miglitol', 
              order = df_raw['miglitol'].value_counts().index,
              data = df_raw,
              hue='readmitted')
plt.xticks(rotation = 90);

# %%
columnas_dropear.append('miglitol')

# %% [markdown]
# ## Troglitazone

# %%
display(df_raw['troglitazone'].value_counts(normalize=True))
# Out:
# No        0.999971
# Steady    0.000029
# Name: troglitazone, dtype: float64

# %%
sns.countplot(x = 'troglitazone', 
              order = df_raw['troglitazone'].value_counts().index,
              data = df_raw,
              hue='readmitted')
plt.xticks(rotation = 90);

# %%
columnas_dropear.append('troglitazone')

# %% [markdown]
# ## Tolazamide

# %%
display(df_raw['tolazamide'].value_counts(normalize=True))
# Out:
# No        0.999617
# Steady    0.000373
# Up        0.000010
# Name: tolazamide, dtype: float64

# %%
sns.countplot(x = 'tolazamide', 
              order = df_raw['tolazamide'].value_counts().index,
              data = df_raw,
              hue='readmitted')
plt.xticks(rotation = 90);

# %%
columnas_dropear.append('tolazamide')

# %% [markdown]
# ## Examide

# %%
display(df_raw['examide'].value_counts(normalize=True))
# Out:
# No    1.0
# Name: examide, dtype: float64

# %%
sns.countplot(x = 'examide', 
              order = df_raw['examide'].value_counts().index,
              data = df_raw,
              hue='readmitted')
plt.xticks(rotation = 90);

# %%
columnas_dropear.append('examide')

# %% [markdown]
# ## Citoglipton

# %%
display(df_raw['citoglipton'].value_counts(normalize=True))
# Out:
# No    1.0
# Name: citoglipton, dtype: float64

# %%
sns.countplot(x = 'citoglipton', 
              order = df_raw['citoglipton'].value_counts().index,
              data = df_raw,
              hue='readmitted')
plt.xticks(rotation = 90);

# %%
columnas_dropear.append('citoglipton')

# %% [markdown]
# ## Insulin

# %%
display(df_raw['insulin'].value_counts(normalize=True))
# Out:
# No        0.465607
# Steady    0.303137
# Down      0.120060
# Up        0.111196
# Name: insulin, dtype: float64

# %%
sns.countplot(x = 'insulin', 
              order = df_raw['insulin'].value_counts().index,
              data = df_raw,
              hue='readmitted')
plt.xticks(rotation = 90);

# %%
columnas_cat.append('insulin')

# %% [markdown]
# ## Glyburide-metformin

# %%
display(df_raw['glyburide-metformin'].value_counts(normalize=True))
# Out:
# No        0.993063
# Steady    0.006800
# Up        0.000079
# Down      0.000059
# Name: glyburide-metformin, dtype: float64

# %%
sns.countplot(x = 'glyburide-metformin', 
              order = df_raw['glyburide-metformin'].value_counts().index,
              data = df_raw,
              hue='readmitted')
plt.xticks(rotation = 90);

# %%
columnas_dropear.append('glyburide-metformin')

# %% [markdown]
# ## Glipizide-metformin

# %%
display(df_raw['glipizide-metformin'].value_counts(normalize=True))
# Out:
# No        0.999872
# Steady    0.000128
# Name: glipizide-metformin, dtype: float64

# %%
sns.countplot(x = 'glipizide-metformin', 
              order = df_raw['glipizide-metformin'].value_counts().index,
              data = df_raw,
              hue='readmitted')
plt.xticks(rotation = 90);

# %%
columnas_dropear.append('glipizide-metformin')

# %% [markdown]
# ## Glimepiride-pioglitazone

# %%
display(df_raw['glimepiride-pioglitazone'].value_counts(normalize=True))
# Out:
# No        0.99999
# Steady    0.00001
# Name: glimepiride-pioglitazone, dtype: float64

# %%
sns.countplot(x = 'glimepiride-pioglitazone', 
              order = df_raw['glimepiride-pioglitazone'].value_counts().index,
              data = df_raw,
              hue='readmitted')
plt.xticks(rotation = 90);

# %%
columnas_dropear.append('glimepiride-pioglitazone')

# %% [markdown]
# ## Metformin-rosiglitazone

# %%
display(df_raw['metformin-rosiglitazone'].value_counts(normalize=True))
# Out:
# No        0.99998
# Steady    0.00002
# Name: metformin-rosiglitazone, dtype: float64

# %%
sns.countplot(x = 'metformin-rosiglitazone', 
              order = df_raw['metformin-rosiglitazone'].value_counts().index,
              data = df_raw,
              hue='readmitted')
plt.xticks(rotation = 90);

# %%
columnas_dropear.append('metformin-rosiglitazone')

# %% [markdown]
# ## Metformin-pioglitazone

# %%
display(df_raw['metformin-pioglitazone'].value_counts(normalize=True))
# Out:
# No        0.99999
# Steady    0.00001
# Name: metformin-pioglitazone, dtype: float64

# %%
sns.countplot(x = 'metformin-pioglitazone', 
              order = df_raw['metformin-pioglitazone'].value_counts().index,
              data = df_raw,
              hue='readmitted')
plt.xticks(rotation = 90);

# %%
columnas_dropear.append('metformin-pioglitazone')

# %% [markdown]
# ## Change

# %%
display(df_raw['change'].value_counts(normalize=True))
# Out:
# No    0.538048
# Ch    0.461952
# Name: change, dtype: float64

# %%
sns.countplot(x = 'change', 
              order = df_raw['change'].value_counts().index,
              data = df_raw,
              hue='readmitted')
plt.xticks(rotation = 90);

# %%
columnas_cat.append('change')

# %% [markdown]
# ## DiabetesMed

# %%
display(df_raw['diabetesMed'].value_counts(normalize=True))
# Out:
# Yes    0.770031
# No     0.229969
# Name: diabetesMed, dtype: float64

# %%
sns.countplot(x = 'diabetesMed', 
              order = df_raw['diabetesMed'].value_counts().index,
              data = df_raw,
              hue='readmitted')
plt.xticks(rotation = 90);

# %%
columnas_cat.append('diabetesMed')

# %% [markdown]
# ## Readmitted (target)

# %%
display(df_raw['readmitted'].value_counts(normalize=True))
# Out:
# NO     0.539119
# >30    0.349282
# <30    0.111599
# Name: readmitted, dtype: float64

# %%
columnas_cat.append('readmitted')

# %% [markdown]
# # Limpieza de datos

# %% [markdown]
# ## Outliers IQR

# %%
def remover_IQR(dataset, column):
    Q1 = dataset[column].quantile(0.25)
    Q3 = dataset[column].quantile(0.75)
    IQR = Q3 - Q1
    df = dataset[~((dataset[column] < (Q1 - 1.5 * IQR)) |(dataset[column] > (Q3 + 1.5 * IQR)))]
    return df

# %% [markdown]
# ## Columnas disponibles

# %%
columnas_cat
# Out:
# ['race',
#  'gender',
#  'age',
#  'tiene_weight',
#  'admission_type_id',
#  'discharge_disposition_id',
#  'admission_source_id',
#  'payer_code',
#  'medical_specialty',
#  'num_procedures',
#  'insulin',
#  'change',
#  'diabetesMed',
#  'readmitted']

# %%
columnas_num
# Out:
# ['time_in_hospital',
#  'num_medications',
#  'number_outpatient',
#  'number_emergency',
#  'number_inpatient',
#  'number_diagnoses']

# %%
df_sin_limpiar = df_raw[columnas_cat + columnas_num]

# %%
df_sin_limpiar.isnull().sum()
# Out:
# race                        0
# gender                      0
# age                         0
# tiene_weight                0
# admission_type_id           0
# discharge_disposition_id    0
# admission_source_id         0
# payer_code                  0
# medical_specialty           0
# num_procedures              0
# insulin                     0
# change                      0
# diabetesMed                 0
# readmitted                  0
# time_in_hospital            0
# num_medications             0
# number_outpatient           0
# number_emergency            0
# number_inpatient            0
# number_diagnoses            0
# dtype: int64

# %%
df_sin_limpiar.dtypes
# Out:
# race                        object
# gender                      object
# age                         object
# tiene_weight                 int32
# admission_type_id            int64
# discharge_disposition_id     int64
# admission_source_id          int64
# payer_code                  object
# medical_specialty           object
# num_procedures               int64
# insulin                     object
# change                      object
# diabetesMed                 object
# readmitted                  object
# time_in_hospital             int64
# num_medications              int64
# number_outpatient            int64
# number_emergency             int64
# number_inpatient             int64
# number_diagnoses             int64
# dtype: object

# %% [markdown]
# ## Race

# %%
df_sin_limpiar['race'].value_counts()
# Out:
# Caucasian          76099
# AfricanAmerican    19210
# ?                   2273
# Hispanic            2037
# Other               1506
# Asian                641
# Name: race, dtype: int64

# %% [markdown]
# ## Age

# %%
df_sin_limpiar['age'].value_counts()
# Out:
# [70-80)     26066
# [60-70)     22482
# [50-60)     17256
# [80-90)     17197
# [40-50)      9685
# [30-40)      3775
# [90-100)     2793
# [20-30)      1657
# [10-20)       691
# [0-10)        161
# Name: age, dtype: int64

# %% [markdown]
# ## Admission type id

# %%
df_sin_limpiar['admission_type_id'].value_counts()
# Out:
# 1    53441
# 3    18763
# 2    18344
# 6     5240
# 5     4775
# 8      319
# 7       20
# 4        9
# Name: admission_type_id, dtype: int64

# %% [markdown]
# ## Discharge disposition id

# %%
df_sin_limpiar['discharge_disposition_id'].value_counts(normalize=True)
# Out:
# 1     0.588646
# 3     0.138580
# 6     0.127651
# 18    0.036674
# 2     0.021061
# 22    0.019769
# 11    0.016278
# 5     0.011724
# 25    0.009497
# 4     0.008104
# 7     0.006026
# 23    0.004097
# 13    0.003968
# 14    0.003699
# 28    0.001382
# 8     0.001054
# 15    0.000626
# 24    0.000477
# 9     0.000199
# 17    0.000139
# 16    0.000109
# 19    0.000080
# 10    0.000060
# 27    0.000050
# 12    0.000030
# 20    0.000020
# Name: discharge_disposition_id, dtype: float64

# %% [markdown]
# ## Admission source id

# %%
df_sin_limpiar['admission_source_id'].value_counts(normalize=True)
# Out:
# 7     0.563773
# 1     0.297468
# 17    0.066664
# 4     0.027591
# 6     0.022369
# 2     0.009945
# 5     0.007584
# 20    0.001803
# 9     0.001338
# 3     0.001059
# 22    0.000128
# 8     0.000116
# 10    0.000093
# 11    0.000023
# 25    0.000023
# 13    0.000012
# 14    0.000012
# Name: admission_source_id, dtype: float64

# %% [markdown]
# ## Time in hospital

# %%
df_sin_limpiar['time_in_hospital'].value_counts(normalize=True)
# Out:
# 3     0.180705
# 2     0.176305
# 1     0.142357
# 4     0.139813
# 5     0.097642
# 6     0.072620
# 7     0.056010
# 8     0.040804
# 9     0.026927
# 10    0.020333
# 11    0.015758
# 12    0.012323
# 13    0.010104
# 14    0.008299
# Name: time_in_hospital, dtype: float64

# %%
df_sin_limpiar = remover_IQR(df_sin_limpiar, 'time_in_hospital')

# %% [markdown]
# ## Payer code

# %%
df_sin_limpiar['payer_code'].value_counts(normalize=True)
# Out:
# 6    0.363479
# 4    0.347157
# 3    0.070239
# 7    0.056346
# 0    0.053619
# 5    0.036715
# 2    0.028769
# 8    0.021883
# 1    0.021793
# Name: payer_code, dtype: float64

# %% [markdown]
# ## N° procedures

# %%
df_sin_limpiar['num_procedures'].value_counts(normalize=True)
# Out:
# 0    0.483425
# 1    0.209959
# 2    0.119066
# 3    0.084617
# 6    0.041624
# 4    0.035761
# 5    0.025548
# Name: num_procedures, dtype: float64

# %%
df_sin_limpiar = remover_IQR(df_sin_limpiar, 'num_procedures')

# %%
fig, axs = plt.subplots(2, figsize = (14,6), sharex = True)

sns.boxplot(x=df_sin_limpiar['num_procedures'], ax=axs[0]);
sns.histplot(
    df_sin_limpiar,
    x="num_procedures",
    multiple="stack",
    edgecolor=".3",
    linewidth=.5,
    ax=axs[1],
);

# %% [markdown]
# ## Nº Diagnoses

# %%
df_sin_limpiar['number_diagnoses'].value_counts(normalize=True)
# Out:
# 9     0.479907
# 7     0.107686
# 8     0.107284
# 6     0.106183
# 5     0.099753
# 4     0.057720
# 3     0.029753
# 2     0.009585
# 1     0.000923
# 16    0.000402
# 10    0.000208
# 11    0.000164
# 13    0.000164
# 15    0.000134
# 12    0.000089
# 14    0.000045
# Name: number_diagnoses, dtype: float64

# %%
df_sin_limpiar = remover_IQR(df_sin_limpiar, 'number_diagnoses')

# %%
fig, axs = plt.subplots(2, figsize = (14,6), sharex = True)

sns.boxplot(x=df_sin_limpiar['number_diagnoses'], ax=axs[0]);
sns.histplot(
    df_sin_limpiar,
    x="number_diagnoses",
    multiple="stack",
    edgecolor=".3",
    linewidth=.5,
    ax=axs[1],
);

# %% [markdown]
# ## Insulin

# %%
df_sin_limpiar['insulin'].value_counts(normalize=True)
# Out:
# No        0.474711
# Steady    0.299217
# Down      0.118745
# Up        0.107327
# Name: insulin, dtype: float64

# %% [markdown]
# ## Change

# %%
df_sin_limpiar['change'].value_counts(normalize=True)
# Out:
# No    0.536916
# Ch    0.463084
# Name: change, dtype: float64

# %% [markdown]
# ## Diabetes Med

# %%
df_sin_limpiar['diabetesMed'].value_counts(normalize=True)
# Out:
# Yes    0.771439
# No     0.228561
# Name: diabetesMed, dtype: float64

# %% [markdown]
# ## Readmitted -> target

# %%
df_sin_limpiar['readmitted'].value_counts(normalize=True)
# Out:
# NO     0.516360
# >30    0.376314
# <30    0.107327
# Name: readmitted, dtype: float64

# %%
df_sin_limpiar['target'] = (df_sin_limpiar['readmitted']=='<30').astype('int')

df_sin_limpiar.drop(['readmitted'],axis=1,inplace=True)

# %%
df_sin_limpiar['target'].value_counts(normalize=True)
# Out:
# 0    0.892673
# 1    0.107327
# Name: target, dtype: float64

# %%
columnas_cat.append('target')

# %% [markdown]
# ## Cambiar Tipo de Dato

# %%
columnas_cat.remove('readmitted')

# %%
for col in columnas_cat:
    df_sin_limpiar[col] = df_sin_limpiar[col].astype('category')

# %%
df_sin_limpiar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 67085 entries, 2 to 101765
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   race                      67085 non-null  category
#  1   gender                    67085 non-null  category
#  2   age                       67085 non-null  category
#  3   tiene_weight              67085 non-null  category
#  4   admission_type_id         67085 non-null  category
#  5   discharge_disposition_id  67085 non-null  category
#  6   admission_source_id       67085 non-null  category
#  7   payer_code                67085 non-null  category
#  8   medical_specialty         67085 non-null  category
#  9   num_procedures            67085 non-null  category
#  10  insulin                   67085 non-null  category
#  11  change                    67085 non-null  category
#  12  diabetesMed               67085 non-null  category
#  13  time_in_hospital          67085 non-null  int64
#  14  num_medications           67085 non-null  int64
#  15  number_outpatient         67085 non-null  int64
#  16  number_emergency          67085 non-null  int64
#  17  number_inpatient          67085 non-null  int64
#  18  number_diagnoses          67085 non-null  int64
#  19  target                    67085 non-null  category
# dtypes: category(14), int64(6)
# memory usage: 4.5 MB

# %% [markdown]
# ## Encoding

# %%
for col in columnas_cat:
    label_encoder = LabelEncoder()
    df_sin_limpiar[col] = label_encoder.fit_transform(df_sin_limpiar[col].values)

# %%
df_sin_limpiar[columnas_num] -= df_sin_limpiar[columnas_num].min()
df_sin_limpiar[columnas_num] /= df_sin_limpiar[columnas_num].max()

# %%
col_dummmies = ['race', 'gender', 'age', 'admission_type_id', 'medical_specialty']
df_sin_limpiar.columns
# Out:
# Index(['tiene_weight', 'admission_type_id', 'discharge_disposition_id',
#        'admission_source_id', 'payer_code', 'medical_specialty',
#        'num_procedures', 'insulin', 'change', 'diabetesMed',
#        'time_in_hospital', 'num_medications', 'number_outpatient',
#        'number_emergency', 'number_inpatient', 'number_diagnoses', 'target',
#        'race_1', 'gender_1', 'age_1', 'age_2', 'age_3', 'age_4', 'age_5',
#        'age_6', 'age_7'],
#       dtype='object')

# %%
for col in col_dummmies:
    df_sin_limpiar = pd.get_dummies(df_sin_limpiar, columns=[col], drop_first=True)

# %%
columnas_box_cox
# Out:
# ['number_outpatient', 'number_emergency']

# %%
encoder = PowerTransformer()
df_sin_limpiar['number_outpatient'] = encoder.fit_transform(df_sin_limpiar['number_outpatient'].values.reshape(-1, 1))

# %%
encoder = PowerTransformer()
df_sin_limpiar['number_emergency'] = encoder.fit_transform(df_sin_limpiar['number_emergency'].values.reshape(-1, 1))

# %% [markdown]
# # Modelado

# %%
df = df_sin_limpiar

# %%
df.head()
# Out:
#     tiene_weight  admission_type_id  discharge_disposition_id  \
# 2              0                  0                         0
# 3              0                  0                         0
# 4              0                  0                         0
# 7              0                  0                         0
# 12             0                  0                         1
#
#     admission_source_id  payer_code  medical_specialty  num_procedures  \
# 2                     1           6                  7               5
# 3                     1           6                  7               1
# 4                     1           6                  7               0
# 7                     1           6                  7               0
# 12                    1           6                  2               0
#
#     insulin  change  diabetesMed  ...  target  race_1  gender_1  age_1  age_2  \
# 2         1       1            1  ...       0       1         0      0      0
# 3         3       0            1  ...       0       0         1      1      0
# 4         2       0            1  ...       0       0         1      0      1
# 7         1       1            1  ...       0       0         1      0      0
# 12        0       0            1  ...       1       0         0      0      1
#
#     age_3  age_4  age_5  age_6  age_7
# 2       0      0      0      0      0
# 3       0      0      0      0      0
# 4       0      0      0      0      0
# 7       0      0      1      0      0
# 12      0      0      0      0      0
#
# [5 rows x 26 columns]

# %%
df.shape
# Out:
# (67085, 26)

# %%
y = df['target']
X = df.loc[:, df.columns != 'target']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = SEED)

# %%
classifiers = []

classifiers.append(LogisticRegression(max_iter=1000, fit_intercept=True, penalty='l2'))
classifiers.append(DecisionTreeClassifier(random_state = 100, max_depth=3, min_samples_leaf=5))
classifiers.append(BernoulliNB(alpha=100))
classifiers.append(GaussianNB())
classifiers.append(SVC())

acc = []
pre = []
rec = []

for clf in classifiers:
    clf.fit(X_train, y_train)
    y_pred= clf.predict(X_test)
    acc_i = accuracy_score(y_test, y_pred)
    pre_i = precision_score(y_test, y_pred)
    rec_i = recall_score(y_test, y_pred)
    
    acc.append((str(clf), acc_i))
    pre.append((str(clf), pre_i))
    rec.append((str(clf), rec_i))
    
    print("Accuracy de '%s': %s"%(clf, acc_i))
    cm = confusion_matrix(y_test, y_pred)
    print("Matriz de Confusión de %s:\n\n%s"%(clf, cm))
    print(classification_report(y_test, y_pred, digits=3))
    print('\n')
# Out:
# Accuracy de 'LogisticRegression(max_iter=1000)': 0.8956140747097882
# Matriz de Confusión de LogisticRegression(max_iter=1000):
#
# [[19787    50]
#  [ 2261    41]]
#               precision    recall  f1-score   support
#
#            0      0.897     0.997     0.945     19837
#            1      0.451     0.018     0.034      2302
#
#     accuracy                          0.896     22139
#    macro avg      0.674     0.508     0.490     22139
# weighted avg      0.851     0.896     0.850     22139
#
#
#
# Accuracy de 'DecisionTreeClassifier(max_depth=3, min_samples_leaf=5, random_state=100)': 0.8962012737702697
# Matriz de Confusión de DecisionTreeClassifier(max_depth=3, min_samples_leaf=5, random_state=100):
#
# [[19823    14]
#  [ 2284    18]]
#               precision    recall  f1-score   support
#
#            0      0.897     0.999     0.945     19837
#            1      0.562     0.008     0.015      2302
#
#     accuracy                          0.896     22139
#    macro avg      0.730     0.504     0.480     22139
# weighted avg      0.862     0.896     0.849     22139
#
#
#
# Accuracy de 'BernoulliNB(alpha=100)': 0.8958850896607796
# Matriz de Confusión de BernoulliNB(alpha=100):
#
# [[19830     7]
#  [ 2298     4]]
#               precision    recall  f1-score   support
#
#            0      0.896     1.000     0.945     19837
#            1      0.364     0.002     0.003      2302
#
#     accuracy                          0.896     22139
#    macro avg      0.630     0.501     0.474     22139
# weighted avg      0.841     0.896     0.847     22139
#
#
#
# Accuracy de 'GaussianNB()': 0.8485478115542707
# Matriz de Confusión de GaussianNB():
#
# [[18407  1430]
#  [ 1923   379]]
#               precision    recall  f1-score   support
#
#            0      0.905     0.928     0.917     19837
#            1      0.210     0.165     0.184      2302
#
#     accuracy                          0.849     22139
#    macro avg      0.557     0.546     0.550     22139
# weighted avg      0.833     0.849     0.840     22139
#
#
#
# Accuracy de 'SVC()': 0.8960205971362754
# Matriz de Confusión de SVC():
#
# [[19837     0]
#  [ 2302     0]]
#               precision    recall  f1-score   support
#
#            0      0.896     1.000     0.945     19837
#            1      0.000     0.000     0.000      2302
#
#     accuracy                          0.896     22139
#    macro avg      0.448     0.500     0.473     22139
# weighted avg      0.803     0.896     0.847     22139
# d:\documents\git\rc_pf\venv\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\documents\git\rc_pf\venv\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\documents\git\rc_pf\venv\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\documents\git\rc_pf\venv\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
